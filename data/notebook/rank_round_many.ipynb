# %%
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt

for path in [f"""../rank_round/050_{i:02}.tsv""" for i in range(20)]:
    df = pl.read_csv("../rank_round/050_00.tsv", has_header=True, separator='\t')
# Out:
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39
# 71
# 39

# %%
hdf = df.pivot(index='round', on='rank', values='count', aggregate_function='sum').fill_null(0).sort('round')

# %%
hdf
# Out:
# shape: (68, 69)
# ┌───────┬─────┬──────┬─────┬───┬─────┬─────┬─────┬─────┐
# │ round ┆ 0   ┆ 1    ┆ 2   ┆ … ┆ 64  ┆ 65  ┆ 66  ┆ 67  │
# │ ---   ┆ --- ┆ ---  ┆ --- ┆   ┆ --- ┆ --- ┆ --- ┆ --- │
# │ i64   ┆ i64 ┆ i64  ┆ i64 ┆   ┆ i64 ┆ i64 ┆ i64 ┆ i64 │
# ╞═══════╪═════╪══════╪═════╪═══╪═════╪═════╪═════╪═════╡
# │ 4     ┆ 0   ┆ 141  ┆ 0   ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# │ 5     ┆ 0   ┆ 711  ┆ 2   ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# │ 6     ┆ 0   ┆ 1793 ┆ 5   ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# │ 7     ┆ 0   ┆ 3684 ┆ 39  ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# │ 8     ┆ 0   ┆ 6473 ┆ 78  ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# │ …     ┆ …   ┆ …    ┆ …   ┆ … ┆ …   ┆ …   ┆ …   ┆ …   │
# │ 67    ┆ 0   ┆ 0    ┆ 0   ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# │ 68    ┆ 0   ┆ 0    ┆ 0   ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# │ 69    ┆ 0   ┆ 0    ┆ 0   ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# │ 70    ┆ 0   ┆ 0    ┆ 0   ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# │ 71    ┆ 0   ┆ 0    ┆ 0   ┆ … ┆ 0   ┆ 0   ┆ 0   ┆ 0   │
# ...

# %%
sns.heatmap(hdf)
# Out:
# <Axes: >

# %%
print(df.filter(pl.col('count') != 0).select(pl.col('round').max()).item())
print(df.filter(pl.col('count') != 0).select(pl.col('rank').max()).item())
# Out:
# 71
# 39

# %%
df[10]
# Out:
# shape: (1, 3)
# ┌───────┬──────┬───────┐
# │ round ┆ rank ┆ count │
# │ ---   ┆ ---  ┆ ---   │
# │ i64   ┆ i64  ┆ i64   │
# ╞═══════╪══════╪═══════╡
# │ 4     ┆ 10   ┆ 0     │
# └───────┴──────┴───────┘
